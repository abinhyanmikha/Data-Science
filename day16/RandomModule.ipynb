# %%
import random

# %%
random.random()#random between (0,1)
# Out:
# 0.245789079903735

# %%
random.uniform(10,20)
# Out:
# 13.222259904129984

# %%
random.randint(1,20)
# Out:
# 11

# %%
random.randrange(10,30,2)
# Out:
# 28

# %%
cards=['nine','ace','jack','king','queen']
random.shuffle(cards)
cards
# Out:
# ['queen', 'king', 'ace', 'jack', 'nine']

# %%
random.choice(cards)
# Out:
# 'ace'

# %%
random.choices(cards,k=3)
# Out:
# ['queen', 'ace', 'king']

# %%
random.sample(cards,k=3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 random.sample(cards,counts=[4]*9,k=3)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\random.py:425, in Random.sample(self, population, k, counts)
#     423 cum_counts = list(_accumulate(counts))
#     424 if len(cum_counts) != n:
# --> 425     raise ValueError('The number of counts does not match the population')
#     426 total = cum_counts.pop() if cum_counts else 0
#     427 if not isinstance(total, int):
#
# ValueError: The number of counts does not match the population
