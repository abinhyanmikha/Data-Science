# %%
import random

# %%
random.random()#random between (0,1)
# Out:
# 0.245789079903735

# %%
random.uniform(10,20)
# Out:
# 13.222259904129984

# %%
random.randint(1,20)
# Out:
# 11

# %%
random.randrange(10,30,2)
# Out:
# 28

# %%
cards=['nine','ace','jack','king','queen']
random.shuffle(cards)
cards
# Out:
# ['queen', 'king', 'ace', 'jack', 'nine']

# %%
random.choice(cards)
# Out:
# 'ace'

# %%
random.choices(cards,k=3)
# Out:
# ['queen', 'ace', 'king']

# %%
random.sample(cards,k=3) #without replacement
# Out:
# ['nine', 'king', 'queen']

# %%
random.normalvariate()
# Out:
# -0.038051975342814744

# %%
random.normalvariate(mu=5,sigma=2.3)
# Out:
# 6.294522954718158

# %%
random.seed(456)
random.random()
# Out:
# 0.7482025358782363

# %%
random.randint(1,100)
# Out:
# 60
