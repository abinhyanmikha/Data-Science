# %%
import os

# %%
if os.path.exists("text"):
    pass
else:
    print("file does not exist")
# Out:
# file does not exist

# %%
os.makedirs("text",exist_ok=True)#make folder without error

# %%
os.path.join("test","file.txt")
# Out:
# 'test\\file.txt'

# %%
os.listdir()
# Out:
# ['OSmodule.ipynb', 'text']

# %%
os.listdrives()
# Out:
# ['C:\\', 'D:\\', 'E:\\', 'F:\\']

# %%
# importing os module  
import os 
import pprint 
  
# Get the list of user's 
env_var = os.environ 
  
# Print the list of user's 
print("User's Environment variable:") 
pprint.pprint(dict(env_var), width = 1)
# Out:
# User's Environment variable:
# {'ALLUSERSPROFILE': 'C:\\ProgramData',
#  'APPDATA': 'C:\\Users\\User\\AppData\\Roaming',
#  'APPLICATION_INSIGHTS_NO_STATSBEAT': 'true',
#  'CHROME_CRASHPAD_PIPE_NAME': '\\\\.\\pipe\\crashpad_10544_FOHRXKAKDHQICAGI',
#  'CLICOLOR': '1',
#  'CLICOLOR_FORCE': '1',
#  'COMMONPROGRAMFILES': 'C:\\Program '
#                        'Files\\Common '
#                        'Files',
#  'COMMONPROGRAMFILES(X86)': 'C:\\Program '
#                             'Files '
#                             '(x86)\\Common '
#                             'Files',
#  'COMMONPROGRAMW6432': 'C:\\Program '
#                        'Files\\Common '
#                        'Files',
#  'COMPUTERNAME': 'LAPTOP-UGSB0M6C',
#  'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe',
#  'COPILOT_OTEL_FILE_EXPORTER_PATH': '\\\\.\\nul',
#  'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
#  'EFC_10444_1262719628': '1',
#  'EFC_10444_1592913036': '1',
#  'EFC_10444_2283032206': '1',
#  'EFC_10444_2775293581': '1',
#  'EFC_10444_3789132940': '1',
#  'EFC_10444_4126798990': '1',
#  'ELECTRON_RUN_AS_NODE': '1',
#  'FORCE_COLOR': '1',
#  'FPS_BROWSER_APP_PROFILE_STRING': 'Internet '
#                                    'Explorer',
#  'FPS_BROWSER_USER_PROFILE_STRING': 'Default',
#  'GIT_PAGER': 'cat',
#  'HOMEDRIVE': 'C:',
#  'HOMEPATH': '\\Users\\User',
#  'JPY_INTERRUPT_EVENT': '1848',
#  'LOCALAPPDATA': 'C:\\Users\\User\\AppData\\Local',
#  'LOGONSERVER': '\\\\LAPTOP-UGSB0M6C',
#  'MPLBACKEND': 'module://matplotlib_inline.backend_inline',
#  'MXC_BIN_DIR': 'c:\\Users\\User\\AppData\\Local\\Programs\\Microsoft '
#                 'VS '
#                 'Code\\a5b5009513\\resources\\app\\node_modules.asar.unpacked\\@microsoft\\mxc-sdk\\bin',
#  'NUMBER_OF_PROCESSORS': '16',
#  'ONEDRIVE': 'C:\\Users\\User\\OneDrive',
#  'ONEDRIVECONSUMER': 'C:\\Users\\User\\OneDrive',
#  'OS': 'Windows_NT',
#  'PAGER': 'cat',
#  'PATH': 'f:\\github\\.venv\\Scripts;F:\\github\\.venv\\Scripts;C:\\xampp\\htdocs;C:\\Windows;C:\\Windows\\System32\\Wbem;C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\;C:\\Windows\\System32\\OpenSSH\\;C:\\Program '
#          'Files '
#          '(x86)\\NVIDIA '
#          'Corporation\\PhysX\\Common;C:\\Program '
#          'Files\\NVIDIA '
#          'Corporation\\NVIDIA '
#          'NvDLISR;C:\\xampp\\htdocs\\php;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\;C:\\WINDOWS\\System32\\OpenSSH\\;C:\\Program '
#          'Files\\Git\\cmd;C:\\Program '
#          'Files\\nodejs\\;C:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python312\\Scripts\\;C:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python312\\;C:\\Users\\User\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\User\\AppData\\Local\\Programs\\Microsoft '
#          'VS '
#          'Code\\bin;C:\\xampp\\php;C:\\Users\\User\\AppData\\Local\\ComposerSetup\\bin;C:\\Users\\User\\AppData\\Roaming\\Composer\\vendor\\bin;C:\\Users\\User\\AppData\\Roaming\\npm;C:\\Users\\User\\AppData\\Local\\Python\\bin',
#  'PATHEXT': '.COM;.EXE;.BAT;.CMD;.VBS;.VBE;.JS;.JSE;.WSF;.WSH;.MSC',
#  'PROCESSOR_ARCHITECTURE': 'AMD64',
#  'PROCESSOR_IDENTIFIER': 'Intel64 '
#                          'Family '
#                          '6 '
#                          'Model '
#                          '186 '
#                          'Stepping '
#                          '2, '
#                          'GenuineIntel',
#  'PROCESSOR_LEVEL': '6',
#  'PROCESSOR_REVISION': 'ba02',
#  'PROGRAMDATA': 'C:\\ProgramData',
#  'PROGRAMFILES': 'C:\\Program '
#                  'Files',
#  'PROGRAMFILES(X86)': 'C:\\Program '
#                       'Files '
#                       '(x86)',
#  'PROGRAMW6432': 'C:\\Program '
#                  'Files',
#  'PROMPT': '(.venv) '
#            '$P$G',
#  'PSMODULEPATH': 'C:\\Program '
#                  'Files\\WindowsPowerShell\\Modules;C:\\WINDOWS\\system32\\WindowsPowerShell\\v1.0\\Modules',
#  'PUBLIC': 'C:\\Users\\Public',
#  'PYDEVD_IPYTHON_COMPATIBLE_DEBUGGING': '1',
#  'PYDEVD_USE_FRAME_EVAL': 'NO',
#  'PYTHONIOENCODING': 'utf-8',
#  'PYTHONUNBUFFERED': '1',
#  'PYTHON_FROZEN_MODULES': 'on',
#  'SESSIONNAME': 'Console',
#  'SYSTEMDRIVE': 'C:',
#  'SYSTEMROOT': 'C:\\WINDOWS',
#  'TEMP': 'C:\\Users\\User\\AppData\\Local\\Temp',
#  'TERM': 'xterm-color',
#  'TMP': 'C:\\Users\\User\\AppData\\Local\\Temp',
#  'USERDOMAIN': 'LAPTOP-UGSB0M6C',
#  'USERDOMAIN_ROAMINGPROFILE': 'LAPTOP-UGSB0M6C',
#  'USERNAME': 'User',
#  'USERPROFILE': 'C:\\Users\\User',
#  'VIRTUAL_ENV': 'F:\\github\\.venv',
#  'VIRTUAL_ENV_PROMPT': '.venv',
#  'VSCODE_CODE_CACHE_PATH': 'C:\\Users\\User\\AppData\\Roaming\\Code\\CachedData\\a5b500951314efd502d07465bd138dfbd714a960',
#  'VSCODE_CRASH_REPORTER_PROCESS_TYPE': 'extensionHost',
#  'VSCODE_CWD': 'C:\\Users\\User\\AppData\\Local\\Programs\\Microsoft '
#                'VS '
#                'Code',
#  'VSCODE_ESM_ENTRYPOINT': 'vs/workbench/api/node/extensionHostProcess',
#  'VSCODE_HANDLES_UNCAUGHT_ERRORS': 'true',
#  'VSCODE_IPC_HOOK': '\\\\.\\pipe\\7a324ef7-1.133.0-main-sock',
#  'VSCODE_L10N_BUNDLE_LOCATION': '',
#  'VSCODE_NLS_CONFIG': '{"userLocale":"en-us","osLocale":"en-us","resolvedLanguage":"en","defaultMessagesFile":"C:\\\\Users\\\\User\\\\AppData\\\\Local\\\\Programs\\\\Microsoft '
#                       'VS '
#                       'Code\\\\a5b5009513\\\\resources\\\\app\\\\out\\\\nls.messages.json","locale":"en-us","availableLanguages":{}}',
#  'VSCODE_PID': '10544',
#  'WINDIR': 'C:\\WINDOWS',
#  'ZES_ENABLE_SYSMAN': '1',
#  '_OLD_VIRTUAL_PATH': 'C:\\xampp\\htdocs;C:\\Windows;C:\\Windows\\System32\\Wbem;C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\;C:\\Windows\\System32\\OpenSSH\\;C:\\Program '
#                       'Files '
#                       '(x86)\\NVIDIA '
#                       'Corporation\\PhysX\\Common;C:\\Program '
#                       'Files\\NVIDIA '
#                       'Corporation\\NVIDIA '
#                       'NvDLISR;C:\\xampp\\htdocs\\php;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\;C:\\WINDOWS\\System32\\OpenSSH\\;C:\\Program '
#                       'Files\\Git\\cmd;C:\\Program '
#                       'Files\\nodejs\\;C:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python312\\Scripts\\;C:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python312\\;C:\\Users\\User\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\User\\AppData\\Local\\Programs\\Microsoft '
#                       'VS '
#                       'Code\\bin;C:\\xampp\\php;C:\\Users\\User\\AppData\\Local\\ComposerSetup\\bin;C:\\Users\\User\\AppData\\Roaming\\Composer\\vendor\\bin;C:\\Users\\User\\AppData\\Roaming\\npm;C:\\Users\\User\\AppData\\Local\\Python\\bin',
#  '_OLD_VIRTUAL_PROMPT': '$P$G'}

# %%
os.environ["SECRETPass"]="abcddfkadfjadsjflkladf"
os.getenv("SECRETPass")
# Out:
# 'abcddfkadfjadsjflkladf'

# %%
os.getenv("OneDrive")
# Out:
# 'C:\\Users\\User\\OneDrive'
