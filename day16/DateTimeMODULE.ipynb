# %%
import datetime

# %%
birth_date=datetime.date(2004,8,15)

# %%
today=datetime.date.today()
age=today-birth_date
age
# Out:
# datetime.timedelta(days=8037)

# %%
age.days/365
# Out:
# 22.019178082191782

# %%
datetime.date.fromtimestamp(178696651)
# Out:
# datetime.date(1975, 8, 31)
