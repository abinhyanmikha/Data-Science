# %%
import pandas as pd

student_df = pd.read_csv("student_survey_clean.csv")

# %%
student_df.head()
# Out:
#    gender  highschool_grade study_year                         faculty  \
# 0  Female              76.0   2nd Year          Arts & Social Sciences
# 1    Male              89.0   2nd Year  Economic & Management Sciences
# 2    Male              76.0   1st Year                    AgriSciences
# 3    Male              89.0   2nd Year                     Engineering
# 4  Female              74.0   2nd Year          Arts & Social Sciences
#
#    ung_grade_2023                                     accomodation  \
# 0            72.0  Private accommodation/ stay with family/friends
# 1            75.0  Private accommodation/ stay with family/friends
# 2            55.0  Private accommodation/ stay with family/friends
# 3            84.0  Private accommodation/ stay with family/friends
# 4            52.0  Private accommodation/ stay with family/friends
#
#          allowance          scholarship study_hours     party_week  \
# ...

# %%
# Target or Features
X = student_df.drop("ung_grade_2023", axis =1 )
Y = student_df[["ung_grade_2023"]]

# %%
X.tail()
# Out:
#      gender  highschool_grade  study_year                         faculty  \
# 373    Male              85.0  Highschool          Arts & Social Sciences
# 374  Female              74.0  Highschool                         Science
# 375  Female              73.0    2nd Year  Economic & Management Sciences
# 376    Male              85.0  Highschool  Economic & Management Sciences
# 377  Female              80.0    1st Year  Economic & Management Sciences
#
#                                         accomodation        allowance  \
# 373                                          Unknown  R 5001 - R 6000
# 374  Private accommodation/ stay with family/friends          Unknown
# 375  Private accommodation/ stay with family/friends  R 6001 - R 7000
# 376  Private accommodation/ stay with family/friends   R 4001- R 5000
# 377  Private accommodation/ stay with family/friends  R 5001 - R 6000
#
#              scholarship study_hours     party_week drinks_night  \
# ...

# %%
# Grouping Categories

# %%
# Label Encoding

# %%
# Normalization
