# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %%
x=np.random.standard_t(500,size=1000)
x[:15]
# Out:
# array([-0.43905806, -0.8418032 , -2.13133589,  1.60507918,  2.25967913,
#        -0.05381013, -0.97417962,  1.06179241, -0.95543317,  0.7212132 ,
#        -0.79860496, -0.14736367, -0.23363951,  1.06683535, -0.14272794])

# %%
_mean=np.mean(x)
print(f"Mean of x :{_mean}")
# Out:
# Mean of x :0.00870773695064155

# %%
plt.hist(x,bins=20,color='blue')
# Out:
# (array([  2.,   3.,   4.,  15.,  28.,  37.,  56.,  83., 106., 108., 117.,
#         123.,  90.,  90.,  57.,  44.,  15.,   8.,   9.,   5.]),
#  array([-3.25214261, -2.9401602 , -2.6281778 , -2.3161954 , -2.004213  ,
#         -1.69223059, -1.38024819, -1.06826579, -0.75628339, -0.44430098,
#         -0.13231858,  0.17966382,  0.49164622,  0.80362863,  1.11561103,
#          1.42759343,  1.73957583,  2.05155824,  2.36354064,  2.67552304,
#          2.98750544]),
#  <BarContainer object of 20 artists>)

# %%
_median=np.median(x)
print(f"Median of x :{_median}")
# Out:
# Median of x :0.026880643323851733

# %%
_mode=stats.mode
