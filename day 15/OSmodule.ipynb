# %%
import os
os.getcwd()
# Out:
# 'f:\\github\\day 15'

# %%
os.mkdir("text.txt")

# %%
os.chdir("text.txt")

# %%
os.getcwd()
# Out:
# 'f:\\github\\day 15\\text.txt'

# %%
os.chdir("..")

# %%
os.getcwd()
# Out:
# 'f:\\github\\day 15'

# %%
if os.path.exists("text.txt"):
    pass
else:
    print("file path does not exist")
