# %%
#magic method-special method that start and end with deouble underscores

# %%
class person:
    """
    hello"""
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def __str__(self):
        return f"{self.name} / {self.age}"
    def ___repr__(self):
        return f"Person({self.name} , {self.age})"
    def __len__(self):
        return self.age
    def __call__(self,gender="male"):
        return f"{self.name} is a {gender}"

# %%
person1=person("abi",21)

# %%
print (person1)
# Out:
# abi / 21

# %%
person1

# %%
len(person1)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 len(person1)

# TypeError: object of type 'person' has no len()
# Out:
# 21

# %%
person1()
# Out:
# 'abi is a male'

# %%
person.__doc__
# Out:
# '\nhello'

# %%
class point:
    def __init__(self,x:int |float,y:int|float):
        self.x=x
        self.y=y
    def __str__(self):
        return f"({self.x},{self.y})"
    def __len__(self):
        return 2
    #operator overloading 
    def __add__(self,other):
        new_x=self.x+other.x
        new_y=self.y+other.y
        return(new_x,new_y)
    def __mul__(self,other):
        new_x=self.x*other.x
        new_y=self.y*other.y
        return point(new_x,new_y)
    def quardent(self):
        if self.x==0 and self.y==0:
            return "Origin point"
        elif self.x==0 or self.y==0:
            return "lies on Axis"
        elif self.x>=0 and self.y>=0:
            return "first quadrant"
        elif self.x<0 and self.y>=0:
            return "second quadrant"
        elif self.x<0 and self.y<0:
            return "third quadrant"
       
        
        
        else:
            return "fourth quadrant"

# %%
p1=point(5,-9)
p2=point(5,1)

# %%
p1.quardent()
# Out:
# 'fourth quadrant'

# %%
p1+p2
# Out:
# (10, -8)

# %%
p3=p1.__add__(p2)
p3
# Out:
# (10, -8)

# %%
p4=p1*p2
p4

# %%
print(p1)
# Out:
# (5,-9)

# %%
len(p1)
# Out:
# 2
