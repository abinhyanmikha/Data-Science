# %%
flag=True
type(flag)
# Out:
# bool

# %%
c=5>7
c
# Out:
# False

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
(6>5) and (4>3) # can use & instead of and
# Out:
# True

# %%
(3>5) or (4>3) #can use | instead of or
# Out:
# True

# %%
not True
# Out:
# False

# %%
bool("z") #non empty string is True
bool("") #empty string is False
# Out:
# False
