# %%
user_profile={
    "name": "john_doe",
    "email": "john@gmail.com",
    "age": 30,
    "skills": ["Python", "JavaScript", "SQL"]
}
marks={
    "Math": 85,
    "Science": 90
}
new_dict=user_profile | marks
new_dict
# Out:
# {'name': 'john_doe',
#  'email': 'john@gmail.com',
#  'age': 30,
#  'skills': ['Python', 'JavaScript', 'SQL'],
#  'Math': 85,
#  'Science': 90}

# %%
{**user_profile, **marks}
# Out:
# {'name': 'john_doe',
#  'email': 'john@gmail.com',
#  'age': 30,
#  'skills': ['Python', 'JavaScript', 'SQL'],
#  'Math': 85,
#  'Science': 90}

# %%
user_profile.update(marks)
user_profile
# Out:
# {'name': 'john_doe',
#  'email': 'john@gmail.com',
#  'age': 30,
#  'skills': ['Python', 'JavaScript', 'SQL'],
#  'Math': 85,
#  'Science': 90}

# %%
user_profile["age"]=85
user_profile
# Out:
# {'name': 'john_doe',
#  'email': 'john@gmail.com',
#  'age': 85,
#  'skills': ['Python', 'JavaScript', 'SQL'],
#  'Math': 85,
#  'Science': 90}

# %%
user_profile={
    "name": "john_doe",
    "email": "john@gmail.com",
    "age": 30,
    "skills": ["Python", "JavaScript", "SQL"],
    "marks":{"maths":85,"science":90}
}

user_profile["marks"]["maths"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 9
#       5     "skills": ["Python", "JavaScript", "SQL"],
#       6     "marks":{"maths":85,"science":90}
#       7 }
#       8
# ----> 9 user_profile["marks"]["maths"]["science"]
#
# TypeError: 'int' object is not subscriptable
