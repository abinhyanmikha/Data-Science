# %%
import re
#library for regex expression

# %%
string="Selenium most commonly refers to a software testing framework used to automate web browsers, or a chemical element with the symbol Se and atomic number 34. "
print(string)
# Out:
# Selenium most commonly refers to a software testing framework used to automate web browsers, or a chemical element with the symbol Se and atomic number 34.

# %%
pattern=r"a"
match=re.search(pattern,string)

# %%
if match:
    print("match start", match.start())
    print("match end", match.end())
# Out:
# match start 33
# match end 34

# %% [markdown]
# (function) def findall(
#  pattern: str | Pattern[str],
#  string: str,
#  flags: _FlagsType = 0
# ) -> list[Any]
#
# Return a list of all non-overlapping matches in the string.
#
# If one or more capturing groups are present in the pattern, return a list of groups; this will be a list of tuples if the pattern has more than one group.
#
# Empty matches are included in the result.

# %%
pattern=r"[A-Z]{2,}"
match=re.findall(pattern,string)

# %%
list(match)
# Out:
# []

# %% [markdown]
# (pattern: str | Pattern[str], repl: str | ((Match[str]) -> str), string: str, count: int = 0, flags: _FlagsType = 0) -> str
#
# Return the string obtained by replacing the leftmost non-overlapping occurrences of the pattern in string by the replacement repl. repl can be either a string or a callable; if a string, backslash escapes in it are processed. If it is a callable, it's passed the Match object and must return a replacement string to be used.

# %%
repla="---"
new_string=re.sub(pattern,repla,string,count=0)

# %%
new_string
# Out:
# 'Selenium most commonly refers to a software testing framework used to automate web browsers, or a chemical element with the symbol Se and atomic number 34. '

# %% [markdown]
# 1/2
# (pattern: str | Pattern[str], string: str, maxsplit: int = 0, flags: _FlagsType = 0) -> list[str | Any]
#
# Split the source string by the occurrences of the pattern, returning a list containing the resulting substrings. If capturing parentheses are used in pattern, then the text of all groups in the pattern are also returned as part of the resulting list. If maxsplit is nonzero, at most maxsplit splits occur, and the remainder of the string is returned as the final element of the list.

# %%
pattern=r"\[\d+\]"# [78] [98]
segment=re.split(pattern,"Help [78], Crazy Bla[2] Bla")

# %%
segment
# Out:
# ['Help ', ', Crazy Bla', ' Bla']
