# %%
print(4,5 , sep='-' ,end="\t")
print(6,7 , sep='-' ,end="\n")
# Out:
# 4-5	6-7

# %%
a=int(input("Enter a number: "))
print(a)
# Out:
# 50

# %%
#if input type not defined it takes data in string format
a=input()
type(a)
# Out:
# str

# %%
type(500==500)
# Out:
# bool

# %%
type(sum)
# Out:
# builtin_function_or_method

# %%
#check type and give result in bool
isinstance(3,int)#used to find if the given obj is instance of python class
# Out:
# True

# %%
isinstance('crazy',str)
# Out:
# True

# %%
len("apple")#count lenght
# Out:
# 5

# %%
abs(-45+4j)
# Out:
# 45.17742799230607

# %%
#all() any()
#all- every thing should be true
#any - if any is true it give true result
a=[False,True,False,False,True]
any(a)
all(a)
# Out:
# False

# %%
complex(1.45)
# Out:
# (1.45+0j)

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to 'utf-8'.
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getitem__(self, key, /)
# ...

# %%
bin(2
    )
# Out:
# '0b10'

# %%
pow(5,2,mod=5)# can do mod after doing power of by the given expno
# Out:
# 0

# %%
round(12.522556,4
      )
# Out:
# 12.5226

# %%
file=open("crazy.txt" ,mode="r+")

file.write("this is a crazy object bla bla")

file.read()
file.close()

# %%
file=open("fot.txt", mode="a+")
file.write("crazy pc")
file.read()
file.close()

# %%
with open("crazy.txt", mode="r+") as file:
    print(file.read())
    file.write("\n Welome to this document")
    print(file.read())
print("file closed")
#log written in w+ format
#readline
#readlines
# Out:
# this is a crazy object bla blaa crazy objectthis is a crazy object bla blathis is a crazy object bla bla
#  Welome to this document
#  Welome to this document
#
# file closed

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
l=[1,2,3]
l.extend("ram")
l
# Out:
# [1, 2, 3, 'r', 'a', 'm']

# %%
f=2.5
f.is_integer()
# Out:
# False

# %%
li=['apple','ball','cat']
en=enumerate(li)
list(en)
# Out:
# [(0, 'apple'), (1, 'ball'), (2, 'cat')]

# %%
for i, name in enumerate(li,start=1):
    print(f"{name} . Roll no. {i}")
# Out:
# apple . Roll no. 1
# ball . Roll no. 2
# cat . Roll no. 3

# %%
#zip()-combine 2 or more iterables
name=["ram","sam",'hari']
marks=[10,20]
crazy=list(zip(name,marks))#zipping 
cra=zip(*crazy)# doing unzip
list(cra)
# Out:
# [('ram', 'sam'), (10, 20)]

# %%
#map() filter() reduce()
