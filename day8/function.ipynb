# %%
print(4,5 , sep='-' ,end="\t")
print(6,7 , sep='-' ,end="\n")
# Out:
# 4-5	6-7

# %%
a=int(input("Enter a number: "))
print(a)
# Out:
# 50

# %%
#if input type not defined it takes data in string format
a=input()
type(a)
# Out:
# str

# %%
type(500==500)
# Out:
# bool

# %%
type(sum)
# Out:
# builtin_function_or_method

# %%
#check type and give result in bool
isinstance(3,int)#used to find if the given obj is instance of python class
# Out:
# True

# %%
isinstance('crazy',str)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 isinstane('crazy',str)
#
# NameError: name 'isinstane' is not defined
