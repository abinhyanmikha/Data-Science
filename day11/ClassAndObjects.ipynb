# %%
class Calculator:
    def __init__(self,num1,num2,*args):
        print("creating objects....")
        self.num1=num1
        self.num2=num2
    def add(self, x,y):
        return x+y
    def sub(self, x,y):
        return x-y
    def mul(self, x,y):
        return x*y
    def div(self, x,y):
        return x/y
red=Calculator(5,4)
# Out:
# creating objects....
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 15
#      11         return x*y
#      12     def div(self, x,y):
#      13         return x/y
#      14 red=Calculator(5,4)
# ---> 15 red.add()
#
# TypeError: Calculator.add() missing 2 required positional arguments: 'x' and 'y'

# %%
class Calculator:
    def __init__(self,num1,num2,*args):
        print("creating objects....")
        self.num1=num1
        self.num2=num2
    def add(self):
        return self.num1+self.num2
    def sub(self):
        return self.num1-self.num2
    def mul(self):
        return self.num1*self.num2
    def div(self):
        return self.num1/self.num2
red=Calculator(5,4)
red.add()
# Out:
# creating objects....
# 9
