# %%
def function(n):
    if(n==1):
        return 1
    
    return n+(n-1)

print(function(5))
# Out:
# 9

# %%
def fib(n):
    if n==0:
        return 0
    elif n==1:
        return 1
    else:
        return fib(n-1)+fib(n-2)

fib(8)
# Out:
# 21

# %%
def fib(n):
    if n==0:
        return 0
    elif n==1:
        return 1
    else:
        return fib(n-1)+fib(n-2)
fib(40)
# Out:
# 102334155

# %%
cache={0:0,1:1}
def fib(n):
    if n in cache:
        return cache[n]
   # if n==0:
       # return 0
    #if n==1:
        #return 1
    else:
        res= fib(n-1)+fib(n-2)
        cache[n]=res
        return res
fib(255)
# Out:
# 87571595343018854458033386304178158174356588264390370

# %%
def factor(n):
    if n==0 or n==1:
     return 1
    return n*factor(n-1)
    
factor(5)
# Out:
# 120

# %%
cache = [1, 1]

def factorial(n):
    if n < len(cache):
        return cache[n]
    else:
        res = n * factorial(n - 1)
        cache.append(res)
        return res

print(factorial(5))
# Out:
# 120

# %% [markdown]
# max line length is 79
