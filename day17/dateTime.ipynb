# %%
import datetime

# %%
strftime("%a-%d %b ,%Y")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 today.strftime("%a-%d %b ,%Y")
#
# NameError: name 'today' is not defined

# %%
dt=datetime.datetime.fromtimestamp(1766223932)
dt
# Out:
# datetime.datetime(2025, 12, 20, 15, 30, 32)

# %%
today=datetime.datetime.now()
today
# Out:
# datetime.datetime(2026, 8, 18, 7, 23, 8, 205900)

# %%
today-dt
# Out:
# datetime.timedelta(days=240, seconds=57156, microseconds=205900)

# %%
#timedelta
year_5=datetime.timedelta(days=5*365)

# %%
year_5
# Out:
# datetime.timedelta(days=1825)

# %%
today+year_5
# Out:
# datetime.datetime(2031, 8, 17, 7, 23, 8, 205900)

# %%
NST=datetime.timezone(datetime.timedelta(hours=5,minutes=45))
NST
# Out:
# datetime.timezone(datetime.timedelta(seconds=20700))

# %%
dt=datetime.datetime(2025,12,3,8,29,55, tzinfo=NST)
dt
# Out:
# datetime.datetime(2025, 12, 3, 8, 29, 55, tzinfo=datetime.timezone(datetime.timedelta(seconds=20700)))

# %%
import time
time.time(
)
# Out:
# 1787017684.0495977

# %%
time.ctime()
# Out:
# 'Tue Aug 18 07:33:08 2026'

# %%
time.gmtime()
# Out:
# time.struct_time(tm_year=2026, tm_mon=8, tm_mday=18, tm_hour=1, tm_min=48, tm_sec=39, tm_wday=1, tm_yday=230, tm_isdst=0)

# %%
#sleep
print("loading>...")
time.sleep(5)
print("completed")
# Out:
# loading>...
# completed

# %%
time.localtime()
# Out:
# time.struct_time(tm_year=2026, tm_mon=8, tm_mday=18, tm_hour=7, tm_min=38, tm_sec=59, tm_wday=1, tm_yday=230, tm_isdst=0)

# %%
time.strftime("%H hour, %M minutes and %S seconds ")
# Out:
# '07 hour, 39 minutes and 07 seconds '

# %%
start=time.time()
print("function started")
time.sleep(3)
print("function ended")
end=time.time()
end-start
# Out:
# function started
# function ended
# 3.0032691955566406
