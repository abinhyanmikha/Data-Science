# %%
print(  "Hello, World!")
# Out:
# Hello, World!

# %%
num=123
type(num)
# Out:
# int

# %%
num=12.54
type(num)
# Out:
# float

# %%
num=5+3j
type(num)
# Out:
# complex

# %%
num=int(2670.99)
type(num)
# Out:
# int

# %%
a=2
b=2.2
c=a+b
print(c)
type(c)
# Out:
# 4.2
# float

# %%
c=6**5
print(c)
# Out:
# 7776

# %%
c=5//2
print(c)
# Out:
# 2

# %%
c=5
d=4
c==d

# %%
print(5==5.0)
# Out:
# True
