# %%
#wap to print hello world
print("hello world")
# Out:
# hello world

# %%
#add 2 numbers
num1=int(input("enter first number:"))
num2=int(input("enter second number:"))
sum=num1+num2
print (sum)
# Out:
# 15

# %%
#find square root of a number
import math
num=int(input("enter a number:"))
sqrt=math.sqrt(num)
print("square root is:",sqrt)
# Out:
# square root is: 5.0

# %%
#area of triangle
base=float(input("enter base of traingle:"))
height=float(input("enter the height:"))
area=0.5*base*height
print("area of traingle is:",area)
# Out:
# area of traingle is: 5.0

# %%
#solve quadratic equation
#ax^2 + bx + c = 0 where a, b and c are real numbers and a != 0
#formula(-b ± (b ** 2 - 4 * a * c) ** 0.5) / (2 * a)
import cmath
a=1
b=5
c=6
if a==0:
    print("a cannot be 0")
else:
 d=(b**2-4*a*c)
 #as there is +_ in formula so we will have 2 solutions
 sol1=(-b+cmath.sqrt(d))/(2*a)
 sol2=(-b-cmath.sqrt(d))/(2*a)
 print("the solution are {0} and {1}".format(sol1,sol2))
# Out:
# the solution are (-2+0j) and (-3-0j)

# %%
#swap two variables
s=5
y="crazy"
print("before swapping s=",s,"y=",y)  
s,y=y,s
print("after swapping s=",s,"y=",y)             
temp=s
s=y
y=temp
print("after swapping again s=",s,"y=",y)
# Out:
# before swapping s= 5 y= crazy
# after swapping s= crazy y= 5
# after swapping again s= 5 y= crazy

# %%
#right to left associative operator
2**2**3
# Out:
# 256

# %%
#random number generator
import random
a= random.randint(1,100)
a
# Out:
# 57

# %%
#convert km to miles
km=float(input("enter a number in km: "))
miles=km*0.62137119
miles
# Out:
# 31.0685595

# %%
#celsius to fahrenheit
celsius=float(input("enter a number in celsius: "))
far=(celsius*9/5)+32
far
# Out:
# 122.0

# %%
#print output without a new line
print("hello", end=" ")
print ("world", end=" ")
print ("crazy ")
# Out:
# hello world crazy
