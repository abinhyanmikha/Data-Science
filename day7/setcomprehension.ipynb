# %%
num=2
new_set=(num**2 for num in range(1,11))
new_set
# Out:
# <generator object <genexpr> at 0x000001E0FAE146C0>

# %%
chars=["c", "a", "b"]
pairs={char1+char2 for char1 in chars for char2 in chars}
pairs
# Out:
# {'aa', 'ab', 'ac', 'ba', 'bb', 'bc', 'ca', 'cb', 'cc'}

# %%
#Problem: Validate and Clean User Input Stream
raw_data = ['150', 'invalid', '80', '204', '999', 'STOP', '300', '450']
cleaned_data=[]
type(raw_data[0])
for data in raw_data:
    #isdigit() method checks if the string consists of digits only
    if data.isdigit():
        if int(data)>100 and int(data)<1000:
            cleaned_data.append(int(data))
cleaned_data.sort()
cleaned_data
##Viral-Load should be in between [100, 999]
 
#Expected Output: [150, 204, 300, 450, 999]
# Out:
# str
