# %%
#right to left      
2**2**3
# Out:
# 256

# %%
0.1+0.2
# Out:
# 0.30000000000000004

# %%
myList=[5,2,7,8,10,1]
myList.sort(reverse=True)# for descending order
myList  
myList.sort()# for ascending order
myList
# Out:
# [1, 2, 5, 7, 8, 10]

# %%
myList=[5,2,7,8,10,1]
myList.reverse() # just reverse the order of the list
myList
a=myList.count(5) #count the number of times 5 appears in the list
a
# Out:
# 1

# %%
myTuple=(5,2,7,8,10,1)#tuple is immutable, we cannot change the values of the tuple
type(myTuple)
max(myTuple) #max value in the tuple    
myTuple[-1] #last value in the tuple
myTuple[0]
myTuple[::2] #slicing the tuple, every second value in the tuple
myTuple[:2]#slicing the tuple, first two values in the tuple
#list is mutable, we can change the values of the list
# Out:
# (5, 2)
