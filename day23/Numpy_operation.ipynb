# %%
import numpy as np

# %%
a= np.array([
    [4,5,8],
    [1,2,4]
]
)

b= np.random.randint(1,45, size= (2,3))
c= np.linspace((0,5), (60,100), num=4,dtype=int)

# %%
np.add(a,b)
# Out:
# array([[40, 18, 45],
#        [12, 30, 20]])

# %%
np.pow(a,2)
# Out:
# array([[16, 25, 64],
#        [ 1,  4, 16]])

# %%
quo,rem=np.divmod(b,a)
rem
# Out:
# array([[0, 3, 5],
#        [0, 0, 0]])

# %% [markdown]
# Trigonometric Operation

# %%
np.sin(a)
# Out:
# array([[-0.7568025 , -0.95892427,  0.98935825],
#        [ 0.84147098,  0.90929743, -0.7568025 ]])

# %%
cot=np.reciprocal(np.tan(b))
cot
# Out:
# array([[ 0.12902442,  2.15972864, -1.18938414],
#        [-0.00442574, -3.55328645,  3.3263232 ]])

# %%
np.around(cot,2)
# Out:
# array([[ 0.13,  2.16, -1.19],
#        [-0.  , -3.55,  3.33]])

# %%
np.floor(cot)
# Out:
# array([[ 0.,  2., -2.],
#        [-1., -4.,  3.]])

# %%
np.ceil(cot)
# Out:
# array([[ 1.,  3., -1.],
#        [-0., -3.,  4.]])

# %%
np.positive(a)
# Out:
# array([[4, 5, 8],
#        [1, 2, 4]])

# %% [markdown]
# Matrix Operation

# %%
#Matrix Multiplication
a.T# for Transpose
# Out:
# array([[4, 1],
#        [5, 2],
#        [8, 4]])

# %%
c=a.transpose()

# %%
c
# Out:
# array([[4, 1],
#        [5, 2],
#        [8, 4]])

# %%
#Matrix Multiplication
#np.dot(a,c)

# %%
res=a.dot(c)

# %%
#Trace (diagonal sum)
d_sum=np.trace(res)
d_sum
# Out:
# np.int64(126)

# %%
#Rank
np.linalg.matrix_rank(a)
# Out:
# np.int64(2)

# %%
#Determinant
np.linalg.det(b)# only square matrix can have determinants
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[32], line 2
#       1 #Determinant
# ----> 2 np.linalg.det(b)# only square matrix can have determinants
#
# File f:\github\.venv\Lib\site-packages\numpy\linalg\_linalg.py:2403, in det(a)
#    2357 """
#    2358 Compute the determinant of an array.
#    2359
#    (...)   2400
#    2401 """
#    2402 a = asarray(a)
# -> 2403 _assert_stacked_square(a)
#    2404 t, result_t = _commonType(a)
#    2405 signature = 'D->D' if isComplexType(t) else 'd->d'
#
# File f:\github\.venv\Lib\site-packages\numpy\linalg\_linalg.py:258, in _assert_stacked_square(*arrays)
#     255     raise LinAlgError(f'{a.ndim}-dimensional array given. Array must be '
#     256                       'at least two-dimensional')
#     257 if m != n:
# --> 258     raise LinAlgError('Last 2 dimensions of the array must be square')
#
# LinAlgError: Last 2 dimensions of the array must be square

# %%
#determinant
import random
d=np.random.randint(1,5, size=(3,3))
det_d=np.linalg.det(d)
det_d
# Out:
# np.float64(-30.000000000000014)

# %%
#Inverse
inv_d=np.linalg.inv(d)
inv_d
# Out:
# array([[-0.5       ,  0.        ,  0.5       ],
#        [ 0.3       ,  0.26666667, -0.36666667],
#        [ 0.3       , -0.06666667, -0.03333333]])

# %%
np.dot(d,inv_d)

# %% [markdown]
# solve: 4x+2y=8,5x+3y=9

# %%
A=np.array([[4,2],[5,3]])
B=np.array([8,9])

A_inv=np.linalg.inv(A)

# %%
X=np.dot(A_inv,B)
X
# Out:
# array([ 3., -2.])

# %%
#Array Broadcasting
A
B
A+B
# Out:
# array([[12, 11],
#        [13, 12]])
