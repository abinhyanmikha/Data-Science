# %%
j=[1,2,3,4,5] # loop for tuples ,list       
for i in j:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
fruits = ["apple", "banana", "cherry"]
for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# cherry

# %%
for i in range(5):#can multiply the string with the number of times you want to print it
    a="*"
    print (a*i)
# Out:
# *
# **
# ***
# ****

# %%
adj=["red", "big", "tasty"]
fruits = ["apple", "banana", "cherry"]
for fruit in fruits:
    for i in adj:
        print(i, fruit)
# Out:
# red apple
# big apple
# tasty apple
# red banana
# big banana
# tasty banana
# red cherry
# big cherry
# tasty cherry

# %%
#multipication table of a given number with range specified by the user
num=5
for i in range(1, 11):
    print(num, 'x', i, '=', num*i)

# Clear the conflicting range variable if needed
del range
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 #multipication table of a given number with range specified by the user
#       2 num=5
# ----> 3 for i in range(1,11):
#       4     print(num, 'x', i, '=', num*i)
#
# TypeError: 'int' object is not callable
