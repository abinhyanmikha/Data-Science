# %%
if 100>10:
        print("100 is greater than 10")
# Out:
# 100 is greater than 10

# %%
a=5
b=10
c=15
if a>b and a>c:
    print("a is the greatest")
elif a<b and a<c:
    print("a is the smallest")
else:
    print("a is neither the greatest nor the smallest")
# Out:
# a is the smallest

# %%
a=int(input("Enter a number: "))
if a%2==0:
    print(f"{a} is an even number")
else:
    print(f"{a} is an odd number")
# Out:
# 1 is an odd number

# %%
x=4
["even","odd"][x%2  ]
# Out:
# 'even'

# %%
x=10
y=-9
if x>0 and y>0:
    print("Both numbers are positive")
elif x>0 or y>0:
    print("At least one number is positive")
else:
    print("both numbers are negative")
# Out:
# At least one number is positive

# %%
#find if given string is palindrome or not
word="robot"

if(word==word[::-1]):
    print(f"{word} is a palindrome")
else:
    print(f"{word} is not a palindrome")
# Out:
# robot is not a palindrome

# %%
# marks to grade conversion
marks=int(input("Enter your marks: "))
if marks>100 or marks<0:
    print("Invalid marks")
else:
    if (marks>=80 and marks<=100):
        print("Grade A")
    elif (marks>=60 ):
        print("Grade B")
    elif (marks>=40):
        print("Grade C")
    else:
        print("Grade F")
# Out:
# Invalid marks

# %%
if[]:# empty list is considered as false
    print("list")
