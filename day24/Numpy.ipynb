# %%
import numpy as np

# %%
a= np.random.randint(10,50, size=(5,4), dtype="int16")
np.shape(a)
# Out:
# (5, 4)

# %%
arr= np.array([1,2,3,4,5])

# %%
print(arr[3])
# Out:
# 4

# %%
arr[2::1]
# Out:
# array([3, 4, 5])

# %%
arr[::-1]
# Out:
# array([5, 4, 3, 2, 1])

# %%
a
# Out:
# array([[43, 20, 41, 23],
#        [25, 36, 18, 47],
#        [23, 17, 35, 22],
#        [27, 30, 26, 33],
#        [37, 16, 16, 24]], dtype=int16)

# %%
a[2,-1]
# Out:
# np.int16(22)

# %%
a[-1,-1]
# Out:
# np.int16(24)

# %%
a[:-1]
# Out:
# array([[43, 20, 41, 23],
#        [25, 36, 18, 47],
#        [23, 17, 35, 22],
#        [27, 30, 26, 33]], dtype=int16)

# %% [markdown]
# SLICING 2D ARRAY First rows sliced and after columns

# %%
a[::]
# Out:
# array([[43, 20, 41, 23],
#        [25, 36, 18, 47],
#        [23, 17, 35, 22],
#        [27, 30, 26, 33],
#        [37, 16, 16, 24]], dtype=int16)

# %%
a[-2,1]
# Out:
# np.int16(30)

# %%
a[-1,-1]
# Out:
# np.int16(24)

# %%
a
# Out:
# array([[43, 20, 41, 23],
#        [25, 36, 18, 47],
#        [23, 17, 35, 22],
#        [27, 30, 26, 33],
#        [37, 16, 16, 24]], dtype=int16)

# %%
a[2:4,1:3]
#array[row_start:row_stop:row_step,col_start:col_stop:col_step]
# Out:
# array([[17, 35],
#        [30, 26]], dtype=int16)

# %%
a[::2]
# Out:
# array([[43, 20, 41, 23],
#        [23, 17, 35, 22],
#        [37, 16, 16, 24]], dtype=int16)

# %%
a[:,-1:]
# Out:
# array([[23],
#        [47],
#        [22],
#        [33],
#        [24]], dtype=int16)

# %%
a
# Out:
# array([[43, 20, 41, 23],
#        [25, 36, 18, 47],
#        [23, 17, 35, 22],
#        [27, 30, 26, 33],
#        [37, 16, 16, 24]], dtype=int16)

# %%
a[2:4,1:3]
# Out:
# array([[17, 35],
#        [30, 26]], dtype=int16)

# %%
a
# Out:
# array([[43, 20, 41, 23],
#        [25, 36, 18, 47],
#        [23, 17, 35, 22],
#        [27, 30, 26, 33],
#        [37, 16, 16, 24]], dtype=int16)

# %%
a[2:4,2:]
# Out:
# array([[35, 22],
#        [26, 33]], dtype=int16)

# %%
a[1:3,2:]
# Out:
# array([[18, 47],
#        [35, 22]], dtype=int16)

# %%
#3D array
np.random.seed(99)
arr=np.random.randint(0,10,size=(3,4,3))

# %%
arr
# Out:
# array([[[1, 3, 9],
#         [8, 9, 8],
#         [2, 4, 5],
#         [4, 1, 7]],
#
#        [[3, 7, 1],
#         [1, 0, 6],
#         [4, 7, 2],
#         [0, 8, 8]],
#
#        [[4, 9, 7],
#         [5, 4, 9],
#         [1, 9, 0],
#         [5, 9, 3]]], dtype=int32)

# %%
#indexing
arr[1,-1:0]
# Out:
# array([], shape=(0, 3), dtype=int32)

# %%
arr.shape
# Out:
# (3, 4, 3)

# %%
arr
# Out:
# array([[[1, 3, 9],
#         [8, 9, 8],
#         [2, 4, 5],
#         [4, 1, 7]],
#
#        [[3, 7, 1],
#         [1, 0, 6],
#         [4, 7, 2],
#         [0, 8, 8]],
#
#        [[4, 9, 7],
#         [5, 4, 9],
#         [1, 9, 0],
#         [5, 9, 3]]], dtype=int32)

# %%
#indexing
arr[1,-1,1]
# Out:
# np.int32(8)

# %%
#slicing
arr[::,1,-2:]
# Out:
# array([[9, 8],
#        [0, 6],
#        [4, 9]], dtype=int32)

# %%
np.random.seed(99)
arr1=np.random.randint(0,10,size=(2,4,4))

# %%
arr1
# Out:
# array([[[1, 3, 9, 8],
#         [9, 8, 2, 4],
#         [5, 4, 1, 7],
#         [3, 7, 1, 1]],
#
#        [[0, 6, 4, 7],
#         [2, 0, 8, 8],
#         [4, 9, 7, 5],
#         [4, 9, 1, 9]]], dtype=int32)

# %%
arr1[1,2,1]
# Out:
# np.int32(9)

# %%
arr1[1:3,]
# Out:
# array([[[0, 6, 4, 7],
#         [2, 0, 8, 8],
#         [4, 9, 7, 5],
#         [4, 9, 1, 9]]], dtype=int32)

# %%
dataset=np.random.randint(0,255, size=(16,1,720,720))

# %%
dataset.shape
# Out:
# (16, 1, 720, 720)

# %%
import matplotlib.pyplot as plt

plt.imshow(dataset[0].reshape(720, 720, -1))
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
