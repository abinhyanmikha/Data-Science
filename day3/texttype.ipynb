# %%
name="Abin"
type(name)
# Out:
# str

# %%
num="54"
int(num)
# Out:
# 54

# %%
address=str("bhaktapur")
type(address)
# Out:
# str

# %%
str.upper(address)
# Out:
# 'BHAKTAPUR'

# %%
a="     crazy    "
a.strip()
# Out:
# 'crazy'

# %%
a.lstrip()
# Out:
# 'crazy    '

# %%
a.rstrip()
# Out:
# '     crazy'

# %%
b=".....crazy....."
b.lstrip(".")
# Out:
# 'crazy.....'

# %%
b.rstrip(".")
# Out:
# '.....crazy'

# %%
b.strip(".")
# Out:
# 'crazy'

# %%
c="cra.zy"
c.replace(".","-")
# Out:
# 'cra-zy'

# %%
c.split(".")
# Out:
# ['cra', 'zy']

# %%
email="student001@info.com"

# %%
# ----@skill.com

# %%
email.endswith("@skill.com") #check if the email ends with @skill.com
# Out:
# False

# %%
"ram".capitalize(
)
# Out:
# 'Ram'

# %%
address="Bangalore India"
address[2]
# Out:
# 'n'

# %%
address[0:5]
# Out:
# 'Banga'

# %%
len(address)
# Out:
# 15

# %%
address[0:15]
# Out:
# 'Bangalore India'

# %%
name1="Ram Chandra Shrestha"
len(name1)
name1[0:20:2] #name[start:end:step]  #start from 0 to 20 and take every second character
# Out:
# 'RmCadaSrsh'

# %%
text="radar"
text[::-1] #reverse the string
text == text[::-1] #check if the string is a palindrome
# Out:
# True

# %%
name="Abin"
age=45
sent="your name is %s and your age is %d"%(name.capitalize(),age)
sent
# Out:
# 'your name is Abin and your age is 45'

# %%
name="Abin"
age=45
ment=f"your name is {name.capitalize()   } and your age is {age  }" #fstring lite 
ment
# Out:
# 'your name is Abin and your age is 45'

# %%
ment=t"your name is {name.capitalize()   } and your age is {age  }" #fstring lite 
ment
# Out:
# Template(strings=('your name is ', ' and your age is ', ''), interpolations=(Interpolation('Abin', 'name.capitalize()', None, ''), Interpolation(45, 'age', None, '')))

# %%
#long string
z="""
c
ra
a
z
y 
"""
print(z)
# Out:
# c
# ra
# a
# z
# y
