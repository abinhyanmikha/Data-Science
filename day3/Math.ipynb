# %%
import math

# %%
def comb(n,k):
    return math.comb(n,k)
comb(5,2)
# Out:
# 10

# %%
math.cbrt(125)
# Out:
# 5.0

# %%
math.dist([1, 2], [4, 6] )
# Out:
# 5.0

# %%
round(math.pi,4)
# Out:
# 3.1416

# %%
math.gcd(12, 18)
# Out:
# 6
