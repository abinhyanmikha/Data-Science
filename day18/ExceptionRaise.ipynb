# %%
number=56.33
if isinstance(number,int):
    print(f"Square root:{number**0.5}")
else:
    raise TypeError(f"value should be int, not {type(number)}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       1 number=56.33
#       2 if isinstance(number,int):
#       3     print(f"Square root:{number**0.5}")
#       4 else:
# ----> 5     raise TypeError(f"value should be int, not {type(number)}")
#
# TypeError: value should be int, not <class 'float'>

# %%
def divide(x,y):
    if y==0:
        raise ValueError("Divisor should not be zero")
    return x/y

# %%
divide(4,0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 divide(4,0)
#
# Cell In[2], line 3, in divide(x, y)
#       1 def divide(x,y):
#       2     if y==0:
# ----> 3         raise ValueError("Divisor should not be zero")
#       4     return x/y
#
# ValueError: Divisor should not be zero

# %%
class MyException(Exception):
    pass

# %%
class InvalidAgeException(Exception):
    """Raise when input is less than 18"""
    pass

# %%
raise InvalidAgeException()
# Out:
# ---------------------------------------------------------------------------
# InvalidAgeException                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 raise InvalidAgeException()
#
# InvalidAgeException:

# %%
def checkcustomer(customer_id):
    age=15
    if "loquitor":
        if age>=18:
            print('good to go')
        else:
            raise InvalidAgeException("must be an adult to buy liqor, age>18")

# %%
checkcustomer(9856)
# Out:
# ---------------------------------------------------------------------------
# InvalidAgeException                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 checkcustomer(9856)
#
# Cell In[14], line 7, in checkcustomer(customer_id)
#       3     if "loquitor":
#       4         if age>=18:
#       5             print('good to go')
#       6         else:
# ----> 7             raise InvalidAgeException("must be an adult to buy liqor, age>18")
#
# InvalidAgeException: must be an adult to buy liqor, age>18

# %%
#ATM
class InvalidWithdraw(Exception):
    """balance less then withdrawl amount"""
    pass

total_amount=2560
def get_cash(withdraw_amt:float):
    if withdraw_amt>total_amount:
        raise InvalidWithdraw("balance less than withdraw_amount")

# %%
get_cash(5000)
# Out:
# ---------------------------------------------------------------------------
# InvalidWithdraw                           Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 get_cash(5000)
#
# Cell In[18], line 9, in get_cash(withdraw_amt)
#       7 def get_cash(withdraw_amt:float):
#       8     if withdraw_amt>total_amount:
# ----> 9         raise InvalidWithdraw("balance less than withdraw_amount")
#
# InvalidWithdraw: balance less than withdraw_amount

# %%
from erros import InvalidAgeException
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 from erros import InvalidAgeException
#
# ModuleNotFoundError: No module named 'erros'
